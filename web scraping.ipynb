# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "http://www.enetcom.rnu.tn/fra/enseignants"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
#print(data)

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
profiles = soup.find_all('div',{'class':'tcard-front'})

# %%
l = []
for profile in profiles : 
    #name
    name = profile.find('div',{'class':'h2'}).text.strip()
    print(name)
    #mail
    mail = profile.find_all('a')[1]
    adress = 'None'
    if len(mail.get('href').strip()) > 7  : 
        #empty strings are of length 7 
        #uncomment the next line to know more
        
        #print(len(mail.get('href').strip()))
        adress = mail.get('href')[7:]
    print(adress)
    #web 
    web_page = profile.find_all('a')[0].get('href')
    print(web_page)
    
    l.append([name,adress,web_page]) 
    
    print('*****************')
# Out:
# CHAABENE Maher
# maher.chaabene@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHER_CHAABENE
# *****************
# ABDELLAOUI Mahmoud
# mahmoud.abdellaoui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHMOUD_ABDELLAOUI
# *****************
# GHARIANI Moez
# Moez.Ghariani@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOEZ_GHARIANI
# *****************
# FAKHFAKH Ahmed
# Ahmed.Fakhfakh@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AHMED_FAKHFAKH
# *****************
# AYADI Moez
# moez.ayadi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOEZ_AYADI
# *****************
# MNIF Hassène
# Hassene.Mnif@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HASSENE_MNIF
# *****************
# AMOUS BEN AMOR Ikram
# ikram.amous@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IKRAM_AMOUS
# *****************
# BEN HAMED Bassem
# bassem.benhamed@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/BASSEM_BENHAMED
# *****************
# CHARFI Salma
# salma.charfi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SALMA_CHARFI
# *****************
# ZARAI Faouzi
# faouzi.zerai@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/FAOUZI_ZARAI
# *****************
# Mohamed Ali Ben Ayed
# Mohamedali.Benayed@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ali_benayed
# *****************
# Directeur ENET'Com
# direction@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/directeur
# *****************
# ABDELMOULA Chokri
# chokri.abdelmoula@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/CHOKRI_ABDELMOULA
# *****************
# FRIKHA Mondher
# mondher.frikha@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MONDHER_FRIKHA
# *****************
# GHORBEL Mohamed
# mohamed.ghorbel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOHAMED_GHORBEL
# *****************
# BEN SLIMA Mohamed
# Mohamed.Benslima@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOHAMED_BENSLIMA
# *****************
# BEN NASR Mounir
# mounir.bennacer@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOUNIR_BENNASR
# *****************
# MASMOUDI Mohamed Salim
# mohamedslim.masmoudi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/slim_masmoudi
# *****************
# ALOUI Helmi
# helmi.aloui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HELMI_ALOUI
# *****************
# FAKHFAKH Mourad
# Mourad.Fakhfakh@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOURAD_FAKHFAKH
# *****************
# TOUNSI Souhir
# souhir.tounsi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOUHIR_TOUNSI
# *****************
# KHEMAKHEM Mahdi
# mahdi.khemakhem@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHDI_KHEMAKHEM
# *****************
# LOUATI Mahdi
# mahdi.louati@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHDI_LOUATI
# *****************
# ABDELKAFI Zied
# Zied.Abdelkafi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ZIED_ABDELKAFI
# *****************
# BEN ATITALLAH Ahmed
# Ahmed.BenAtitallah@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AHMED_BENATITALLAH
# *****************
# KHARRAT Maher
# maher.kharrat@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHER_KHARRAT
# *****************
# KHARRAT Wajdi
# mohamedwajdi.kharrat@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/WAJDI_KHARRAT
# *****************
# TAOUIL Khaled
# khaled.taouil@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/KHALED_TAOUIL
# *****************
# TRIKI Moncef
# moncef.triki@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MONCEF_TRIKI
# *****************
# BOUJELBEN Yassine
# yassine.boujelben@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/YASSINE_BOUJELBEN
# *****************
# Rim Ayadi Marzouk
# rim.marzouk@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RIM_AYADI
# *****************
# BEN SALEM Samir
# Samir.BenSelem@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SAMIR_BENSALEM
# *****************
# HAJJI Messaoud
# messaoud.hajji@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MESSAOUD_HAJJI
# *****************
# MNIF Kais
# kais.mnif@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/KAIS_MNIF
# *****************
# FAKHFAKH Nadim
# Nadim.Fakhfakh@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NADIM_FAKHFAKH
# *****************
# FRIKHA Soulef
# soulef.frikha@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOULEF_FRIKHA
# *****************
# MAROUANE Hend
# hend.marouane@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HEND_MAROUANE
# *****************
# MASMOUDI Anis
# anis.masmoudi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ANIS_MASMOUDI
# *****************
# Fahmi GHOZZI
# Fahmi.Ghozzi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/FAHMI_GHOZZI
# *****************
# KOUBAA Hend
# hend.koubaa@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HEND_KOUBAA
# *****************
# LOUKIL Hassen
# Hassen.Loukil@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HASSEN_LOUKIL
# *****************
# KHROUF Kaïs
# kais.khrouf@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/KAIS_KHROUF
# *****************
# KALLEL Mohamed
# mohamed.kallel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOHAMED_KALLEL
# *****************
# MAKNI Achraf
# achraf.makni@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ACHRAF_MAKNI
# *****************
# ABBES Tarek
# tarek.abbes@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/TAREK_ABBES
# *****************
# FEKI Salima
# Salima.Feki@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SALIMA_FEKI
# *****************
# BOUCHHIMA Faouzi
# faouzi.bouchhima@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/FAOUZI_BOUCHHIMA
# *****************
# REKIK Neila
# Neila.Rekik@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NEILA_REKIK
# *****************
# AMOURI LOULOU Imen
# imen.amouri@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IMEN_AMOURI
# *****************
# MAKHLOUFI Achraf
# achraf.makhloufi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ACHRAF_MAKHLOUFI
# *****************
# KSANTINI Nesrine
# Nisrine.Kossentini@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NESRINE_KSANTINI
# *****************
# GOMRI Sami
# Sami.gomri@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SAMI_GOMRI
# *****************
# SAMET Amine
# amine.samet@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AMINE_SAMET
# *****************
# CHAARI Tarak
# tarak.chaari@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/TARAK_CHAARI
# *****************
# MEGDICH Nadia
# nedia.megdich@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NADIA_MEGDICH
# *****************
# AMOURI Lobna
# lobna.amouri@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/LOBNA_AMOURI
# *****************
# BEN AMOR Nidhal
# Nidhal.Benamor@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NIDHAL_BENAMOR
# *****************
# CHAABOUNI Sihem
# sihem.chaabouni@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SIHEM_CHAABOUNI
# *****************
# Mtibaa Achraf
# achraf.mtibaa@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ACHRAF_MTIBAA
# *****************
# MAJDOUBI Jihen
# jihen.majdoubi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/JIHEN_MAJDOUBI
# *****************
# HADJ-KACEM Imed
# imed.hadjkacem@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IMED_HADJ-KACEM
# *****************
# MEDDEB MAKHLOUF Amel
# amel.makhlouf@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AMEL_MEDDEB
# *****************
# GASSARA Bilel
# Bilel.gassara@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/BILEL_GASSARA
# *****************
# OMHENI Nouri
# nouri.omheni@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NOURI_OMHENI
# *****************
# BOUJELBENE Manel
# manel.boujelben@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MANEL_BOUJELBENE
# *****************
# KALLEL Fathi
# fathi.kallel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/FATHI_KALLEL
# *****************
# HACHICHA Fatma
# fatma.hachicha@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/FATMA_HACHICHA
# *****************
# BEN SALAH Ibrahim
# ibrahim.bensalah@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IBRAHIM_BENSALAH
# *****************
# DAMAK Taheni
# taheni.dammak@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/TAHENI_DAMAK
# *****************
# FAKHFAKH CHAARI Kaouthar
# kaouthar.fakhfakh@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/KAOUTHAR_FAKHFAKH
# *****************
# MASMOUDI Wafa
# wafa.masmoudi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/WAFA_MASMOUDI
# *****************
# GARGOURI Amir
# Amir.Gargouri@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AMIR_GARGOURI
# *****************
# BEN AOUN Najib
# najib.benaoun@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NAJIB_BENAOUN
# *****************
# HENTATI Manel
# Manel.Hentati@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MANEL_HENTATI
# *****************
# KHALFALLAH Ali
# ali.Khalfallah@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ALI_KHALFALLAH
# *****************
# ELLOUZE Nebrasse
# nebrasse.ellouze@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NEBRASSE_ELLOUZE
# *****************
# ZOUCH Wassim
# wassim.zouch@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/WASSIM_ZOUCH
# *****************
# DAOUD DAMAK Houda
# Houda.Daoud@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HOUDA_DAOUD
# *****************
# BELGHITH Aymen
# aymen.belghith@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/AYMEN_BELGHITH
# *****************
# Salwa SAHNOUN
# saloua.sahnoun@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SALWA_FAKHFAKH
# *****************
# FOURATI KALLEL Imen
# imen.fourati@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IMEN_FOURATI
# *****************
# SMAOUI Ikram
# ikram.smaoui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IKRAM_SMAOUI
# *****************
# GUIDARA Rima
# rima.guidara@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RIMA_GUIDARA
# *****************
# SFAYHI Imen
# imen.sfaihi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IMEN_SFAYHI
# *****************
# MLIKI Hazar
# hazar.mliki@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HAZAR_MLIKI
# *****************
# HAKIM Hela
# hela.hakim@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HELA_HAKIM
# *****************
# BEN HASSEN Sonia
# sonia.benhassen@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SONIA_BENHASSEN
# *****************
# OUNI Tarak
# tarak.ouni@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/TARK_OUNI
# *****************
# DERBEL Hajer
# hajer.derbel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HAJER_DERBEL
# *****************
# AYADI Rawia
# rawia.ayadi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RAWIA_AYADI
# *****************
# KALLEL Emna
# emna.kallel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/EMNA_KALLEL
# *****************
# MASMOUDI Abdelkarim
# abdelkarim.masmoudi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ABDELKARIM_MASMOUDI
# *****************
# KOUBAA Mohamed
# mohamed.koubaa@enetcom.rnu.tn
# http://www.enetcom.rnu.tn/fra/profil/MOHAMED_KOUBAA
# *****************
# BEN SAID Tarak
# tarak.bensaid@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/TARAK_BENSAID
# *****************
# BOUCHAALA  Lobna
# lobna.bouchaala@enetcom.usf.n
# http://www.enetcom.rnu.tn/fra/profil/LOBNA_BOUCHAALA
# *****************
# NEJI Mohamed
# mohamed.neji@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOHAMED_NEJI
# *****************
# CHAKER Nadia
# nadia.chaker@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NADIA_CHAKER
# *****************
# JAMOUSI Kais
# kais.jamousi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/KAIS_JAMOUSI
# *****************
# HENTATI Raida
# raida.hentati@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RAIDA_HENTATI
# *****************
# BLAIECH Rabeb
# rabeb.blaiech@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RABEB_BLAIECH
# *****************
# BRADAI Nourchene
# nourchene.bradai@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NOURCHENE_BRADAI
# *****************
# ZAAFRANE Habiba
# habiba.zaafrane@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HABIBA_ZAAFRANE
# *****************
# GASSARA Hela
# hela.gassara@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HELA_GASSARA
# *****************
# HAJJI Sofiene
# sofien_hajji@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOFIENE_HAJJI
# *****************
# AMMAR Sonda
# sonda.ammar@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SONDA_AMMAR
# *****************
# Salima Smaoui
# salima.smaoui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/salima_smaoui
# *****************
# Boukthir Haddar
# boukthir.haddar@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/boukthir_haddar
# *****************
# SMAOUI Soulaimen
# soulaimen.smaoui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOULAIMEN_SMAOUI
# *****************
# MASMOUDI Mouna
# mouna.masmoudi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MOUNA_MASMOUDI
# *****************
# SHABOU Sonda
# Sonda.Shabou@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SONDA_SHABOU
# *****************
# TRIKI Sami
# sami.triki@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SAMI_TRIKI
# *****************
# SMAOUI Souhail
# souhail.smaoui@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOUHAIL_SMAOUI
# *****************
# MARRAKCHI Sonia
# sonia.marrekchi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SONIA_MARRAKCHI
# *****************
# ELSAFI Bassem
# Bassem.safi@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/BASSEM_ELSAFI
# *****************
# Fatma GHORBEL
# None
# http://www.enetcom.rnu.tn/fra/profil/Fatma-Ghorbel
# *****************
# Sassia Rahali
# rahali.sassia@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/sassia_rahali
# *****************
# MILADI HBAEIB Leila
# leila.hbaieb@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/LEILA_MILADI
# *****************
# ELLOUZE Adnen
# adnen.ellouz@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ADNEN_ELLOUZE
# *****************
# KSENTINI Jihene
# jihene.kessentini@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/JIHENE_KSENTINI
# *****************
# Rihab Maaloul
# rihab.maaloul.abid@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/rihab_maaloul
# *****************
# Fatma Loussaief
# fatma92.loussaief@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/fatma_loussaief
# *****************
# Dalia Fendri
# dalia.fendri@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/dalia_fendri
# *****************
# Sawsan Lahiyani
# sawssenlahiani@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/sawsan_lahiyani
# *****************
# Mouna Kotti
# kot.mouna@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/mouna_kotti
# *****************
# Kawthar Kammoun
# kaoutharkammoun@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/kawthar_kammoun
# *****************
# Imene Ghorbel
# None
# http://www.enetcom.rnu.tn/fra/profil/imen_ghorbel
# *****************
# Bassem HadjKacem
# None
# http://www.enetcom.rnu.tn/fra/profil/bassem_hadjkacem
# *****************
# Nesrine Charfi
# charfi.nesrine@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/nesrine-charfi
# *****************
# Hedi Amri
# None
# http://www.enetcom.rnu.tn/fra/profil/hedi-amri
# *****************
# Nesrine Trabelsi
# None
# http://www.enetcom.rnu.tn/fra/profil/nesrine_trabelsi
# *****************
# Leila Ghorbel
# leila.ghorbel@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/leila_ghorbel
# *****************
# Hind Hallabia
# hallabia.hind@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/hind_hallabia
# *****************
# Abdelmoula Faycel
# None
# http://www.enetcom.rnu.tn/fra/profil/abdelmoula_faycel
# *****************
# Rahma Abid
# None
# http://www.enetcom.rnu.tn/fra/profil/rahma_abid
# *****************
# Achraf Ben Hmedou
# None
# http://www.enetcom.rnu.tn/fra/profil/achraf_benhmedou
# *****************
# Ahmed Ben Jmeaa
# None
# http://www.enetcom.rnu.tn/fra/profil/ahmed_benjmeaa
# *****************
# Nesrine Elloumi
# None
# http://www.enetcom.rnu.tn/fra/profil/nesrine_elloumi
# *****************
# Khalil Gassara
# None
# http://www.enetcom.rnu.tn/fra/profil/khalil_gassara
# *****************
# Agnes Ghorbel
# None
# http://www.enetcom.rnu.tn/fra/profil/agnes_ghorbel
# *****************
# Khalil Hammami
# khalil@exydev.tn
# http://www.enetcom.rnu.tn/fra/profil/khammami
# *****************
# Imen Jammoussi
# None
# http://www.enetcom.rnu.tn/fra/profil/imen_jammoussi
# *****************
# Nadia Smaoui
# None
# http://www.enetcom.rnu.tn/fra/profil/nadia_smaoui
# *****************
# Mouna Zouari
# None
# http://www.enetcom.rnu.tn/fra/profil/mouna_zouari
# *****************
# Hanen Lajnef
# lajnefhanen76@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/hanen_lajnef
# *****************
# Rym Chéour
# cheourr@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/rym_chéour
# *****************
# Malek Rekik
# 22.malek@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/Malek_Rekik
# *****************
# Ferdaous Kamoun
# abidkamounferdaous@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/ferdaous_kamoun
# *****************
# Hanen Ellouze
# ellouze.hanen@hotmail.fr
# http://www.enetcom.rnu.tn/fra/profil/hanen_ellouze
# *****************
# Sirine Ben Ameur
# ben.ameur.sirine.1986@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/sirine_benameur
# *****************
# Faten Baklouti
# faten.baklouti@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/faten_baklouti
# *****************
# Hanen Ben Ayed
# benayed.hanen@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/hanen_benayed
# *****************
# Walid  Ben Ayed
# walid.benayed@imsr.tn
# http://www.enetcom.rnu.tn/fra/profil/walid_benayed
# *****************
# Amina Masmoudi
# aminamasmoudi2013@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/amina_masmoudi
# *****************
# Ghada Feki
# ghada.feki@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ghada_feki
# *****************
# DAOUD  Yassine
# None
# http://www.enetcom.rnu.tn/fra/profil/YASSINE_DAOUD
# *****************
# AMMAR Mourad
# None
# http://www.enetcom.rnu.tn/fra/profil/MOURAD_AMMAR
# *****************
# JARRAYA Aref
# None
# http://www.enetcom.rnu.tn/fra/profil/AREF_JARRAYA
# *****************
# walid bouzayani
# bouzayaniwalid2000@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/WALID_BOUZAYENE
# *****************
# BOUJELBENE Helmi
# None
# http://www.enetcom.rnu.tn/fra/profil/HELMI_BOUJELBEN
# *****************
# MNIF Sami
# None
# http://www.enetcom.rnu.tn/fra/profil/SAMI_MNIF
# *****************
# HACHICHA Radhouane
# None
# http://www.enetcom.rnu.tn/fra/profil/RADHOUANE_HACHICHA
# *****************
# OUTHINI Youssef
# None
# http://www.enetcom.rnu.tn/fra/profil/YOUSSEF_OUTHINI
# *****************
# NEJI Baligh
# None
# http://www.enetcom.rnu.tn/fra/profil/BALIGH_NEJI
# *****************
# DAMMAK Houssem
# None
# http://www.enetcom.rnu.tn/fra/profil/HOUSSEM_DAMMAK
# *****************
# BELKHIRE Yassine
# None
# http://www.enetcom.rnu.tn/fra/profil/YASSINE_BELKHIRE
# *****************
# TAKTAK Morched
# None
# http://www.enetcom.rnu.tn/fra/profil/MORCHOD_TAKTAK
# *****************
# FAKHFAKH Ibtissem
# ibtissem_fakhfakh@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/IBTISSEM_FAKHFAKH
# *****************
# MNEJA Imene
# None
# http://www.enetcom.rnu.tn/fra/profil/IMENE_MNEJA
# *****************
# HAMIDAT Zahra
# None
# http://www.enetcom.rnu.tn/fra/profil/ZAHRA_HAMIDAT
# *****************
# LOUKIL Wajdi
# None
# http://www.enetcom.rnu.tn/fra/profil/WAJDI_LOUKIL
# *****************
# DHIAB Youssef
# None
# http://www.enetcom.rnu.tn/fra/profil/YOUSSEF_DHIAB
# *****************
# GADDOUR Tarak
# None
# http://www.enetcom.rnu.tn/fra/profil/TARAK_GADDOUR
# *****************
# AMMAR Marwa
# None
# http://www.enetcom.rnu.tn/fra/profil/MARWA_AMMAR
# *****************
# MASMOUDI Ahmed
# None
# http://www.enetcom.rnu.tn/fra/profil/AHMED_MASMOUDI
# *****************
# Mohamed KHARRAT
# mohamed.kharrat@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/mohamed_kharrat
# *****************
# Amal  Hammami
# amal.hammami.expert@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/amal_hammami
# *****************
# Mouna Lahiyani
# telesys@telesys.tn
# http://www.enetcom.rnu.tn/fra/profil/mouna_lahiyani
# *****************
# Fakher Chaari
# fakher.chaari@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/fakher_chaari
# *****************
# Faouzi Derbel
# faouzi.derbel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/faouzi_derbel
# *****************
# Olfa Kanoun
# olfa.kanoun@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/olfa_kanoun
# *****************
# KAMOUN Sourour
# sourour.kallel@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/SOUROUR_KAMOUN
# *****************
# BEN SALAH Lasaad
# lassaad.bensalah@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/LASAAD_BENSALAH
# *****************
# BAHLOUL Bassem
# bassem.bahloul@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/BASSEM_BAHLOUL
# *****************
# KARRAY Mahmoud
# mahmoud.karray@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/MAHMOUD_KARRAY
# *****************
# BECHA TAKTAK Nihel
# nihel.becha@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/NIHEL_BECHA
# *****************
# HACHED Rim
# rim.hached@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/RIM_HACHED
# *****************
# Ali M. AMRI
# ali.amri@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/ALI_AMRI
# *****************
# LAHIANI Houcem
# houcem.lahiani@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/HOUCEM_LAHIANI
# *****************
# BOUCHHIMA Imen
# imen.bouchhima@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/IMEN_BOUCHHIMA
# *****************
# Karim Jaber
# karim.jaber@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/karim_jaber
# *****************
# Achraf Ben Hamadou
# achraf.benhamadou@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/achraf_benhamedou
# *****************
# Mouna Sahnoun
# mounasahnoun2@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/mouna_sahnoun
# *****************
# Kaouthar Jmal
# kaoithardjemel@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/kaouthar_jmal
# *****************
# Wiem Elleuch
# elleuchwiam@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/wiam_elleuch
# *****************
# Fatma Baccar
# fatma.baccar@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/fatma_baccar
# *****************
# Ahlem Masmoudi
# ahlem.massmoudi@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/ahlem_masmoudi
# *****************
# Afef Salhi
# salhiafefge@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/afef_salhi
# *****************
# Wafa Wali
# wafa.wali@fsegs.rnu.tn
# http://www.enetcom.rnu.tn/fra/profil/wafa_wali
# *****************
# Emna Guermazi
# guermaziemna1@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/emna_guermazi
# *****************
# Meriam Tayari
# None
# http://www.enetcom.rnu.tn/fra/profil/tayari_meriam
# *****************
# Mohamed Yaich
# yaich_fr2000@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/mohamed_yaich
# *****************
# Oumaya Belaaj
# None
# http://www.enetcom.rnu.tn/fra/profil/oumaya_belaaj
# *****************
# Syrine Jmal
# None
# http://www.enetcom.rnu.tn/fra/profil/syrine_jmal
# *****************
# Maysa Daoud
# None
# http://www.enetcom.rnu.tn/fra/profil/daoud_maysa
# *****************
# Nawres Ben Fatma
# None
# http://www.enetcom.rnu.tn/fra/profil/nawres_benfatma
# *****************
# Mohamed Kammoun
# None
# http://www.enetcom.rnu.tn/fra/profil/mohamed_kammoun
# *****************
# Dhoha Ghrab
# ghrab.dhoha@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/dhoha_ghrab
# *****************
# Fatma SESSI
# None
# http://www.enetcom.rnu.tn/fra/profil/fatma_sessi
# *****************
# Ahmed Hammami
# ahmed.hammami2109@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/Ahmed_Hammami
# *****************
# Neila Zaalani
# neila.zaalani@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/neila_zaalani
# *****************
# Maroua Ben Belgacem
# marouabenbelgacem@yahoo.fr
# http://www.enetcom.rnu.tn/fra/profil/maroua_benbelgacem
# *****************
# Rim Zghal
# rim.zghal@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/rim_zghal
# *****************
# Raouia Khelif
# raouia.khelif1992@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/raouia_khelif
# *****************
# Mouna Torjmen
# mouna.torjmen@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/mouna_torjmen
# *****************
# Mariem Fourati
# mariem.fourati@enetcom.u-sfax.tn
# http://www.enetcom.rnu.tn/fra/profil/mariem_fourati
# *****************
# Wasma Hanini
# wasma.hanini@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/wasma_hanini
# *****************
# Abir BOUJELBEN
# abir.boujelben@enetcom.usf.tn
# http://www.enetcom.rnu.tn/fra/profil/abir_boujelben
# *****************
# Azza Allouch
# azza.allouch@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/azza_allouch
# *****************
# Ines Ben Massoud
# ines.benmassoud@gmail.com
# http://www.enetcom.rnu.tn/fra/profil/ines_benmassoud
# *****************

# %%
import pandas as pd 
df = pd.DataFrame(l,columns=['name','email','webpage'])

# %%
df.head()
# Out:
#                  name                              email  \
# 0      CHAABENE Maher      maher.chaabene@enetcom.usf.tn
# 1  ABDELLAOUI Mahmoud  mahmoud.abdellaoui@enetcom.usf.tn
# 2       GHARIANI Moez       Moez.Ghariani@enetcom.usf.tn
# 3      FAKHFAKH Ahmed      Ahmed.Fakhfakh@enetcom.usf.tn
# 4          AYADI Moez          moez.ayadi@enetcom.usf.tn
#
#                                              webpage
# 0  http://www.enetcom.rnu.tn/fra/profil/MAHER_CHA...
# 1  http://www.enetcom.rnu.tn/fra/profil/MAHMOUD_A...
# 2  http://www.enetcom.rnu.tn/fra/profil/MOEZ_GHAR...
# 3  http://www.enetcom.rnu.tn/fra/profil/AHMED_FAK...
# 4    http://www.enetcom.rnu.tn/fra/profil/MOEZ_AYADI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     219 non-null    object
#  1   email    219 non-null    object
#  2   webpage  219 non-null    object
# dtypes: object(3)
# memory usage: 5.3+ KB

# %%
df.to_csv('enetcom staff.csv',index=False)
